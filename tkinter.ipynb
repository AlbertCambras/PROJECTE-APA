# %% [markdown]
# **TKINTER**
# =========

# %% [markdown]
# Tot són widgets:
#
# Tk()
# ----
#
# Tenim el widget **root** --> Finestra principal
# ```py
# root = Tk() #finestra principal
# root.title("") # nom finestra
# root.iconbitmap('Direcció icono') # icono finestra
# ```
# ETIQUETA
# ---------
# ```py
# etiqueta = Label(root, text="") # etiqueta de text
#
# etiqueta.pack() # fer que es vegi la etiqueta
#
# ```
# BOTONS
# ------
# ```py
# b = Button(root, text="", padx= ,pady=, command=function() ) # pad=padding, espai que deixes
#
# ```
# ATRIBUTS
#
# text
# padx,pady
# command
# fg --> foreground color
# bg --> background color
#
#
#
# INPUT TEXT
# ----------
# ```py
#
# e = Entry(root, width=50)
#
# e.get() # get el que hagi escrit (string)
# ```
# ATRIBUTS
#
# text
# borderwidth
# width
# bg
# fg
#
# MESSAGE BOXES
# -------------
# ```py
# def popup():
#     messagebox.showinfo("This is my message box", "Desea salir?") # this is my... title of window
#     # showinfo, showwarning, showerror, askquestion, askokcancel...
#
#     # al apretar un botó pot retornar 0 o 1 segons yes or not
#     Label(root,text=response).pack
#     if response == 1:
#         ...
#
# Button(root, text="Quitar", command=popup).pack()
# ```
#
# **TREBALLAR AMB IMATGES**
# ------------------------
# S'HA D'UTILITZAR PILLOW
#
# ```py
# from PIL import ImageTk ,Image
#
# # declarem imatge
# img = ImageTk.PhotoImage(Image.open("foto.png"))
#
# # hem de ficar la imatge en algun container
# etiqueta = Label(image = img)
#
# # la mostrem
# etiqueta.pack()
#
# # SI HEM DE OPERAR AMB LA IMATGE...
# img = Image.open("foto.png")
# pixels = img.load()
#
# #representacio
# imatge = ImageTk.Photoimage(img)
# etiqueta...
# ```
#
# OBRIR UN GESTOR DE FITXERS
# ---------------------------
# ```py
# root.filename = filedialog.askopenfilename(initialdir='/...', title="Select a JPG file", filetypes=(("png files", "*.png"), ("all files", "*.*")))
# # sapiguer nom de lftixer una vegada obert
# root.filename
#
# ```
#
# ORGANIZACIÓ EN FILES I COLUMNES
# -------------------------------
# ```py
#
# et1 = Label(root, text="et1")
# et2 = Label(root, text="et2")
#
# # FIQUEM LES ETIQUETES EN LA MATEIXA COLUMNA
# et1.grid(row=0, column=0)
# et2.grid(row=1,column=0)
# # per a poder ficar coses a les altres columnes ex.4, s'ha de ficar alguna cosa a la 2,3
# ```
#
# LOOP FINESTRA
# -------------
# ```py
# root.mainloop() # bucle per a visualitzar finestra principal
# ```

# %%
from tkinter import *
